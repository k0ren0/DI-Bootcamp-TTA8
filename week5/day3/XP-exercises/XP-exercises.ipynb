# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🌟 Exercise 2 :

# %%
x = [1, 2, 3, 4, 5]  # Prices
y = [5, 4, 3, 2, 1]  # Demand

plt.plot(x, y,)

plt.plot(
    xlabel='Prices',
    ylabel='Demand',
    title='Demand for a Product at Different Price Points'
)
plt.show()

# %% [markdown]
# ## 🌟 Exercise 3 :

# %%
x = [1, 2, 3, 4, 5]  # Age
y = [75, 80, 88, 95, 105]  # Height in cm

plt.scatter(x, y)

plt.xlabel('Age')
plt.ylabel('Height (cm)')
plt.title("Children's Heights at Different Ages")
plt.show()

# %% [markdown]
# ## 🌟 Exercise 4 :

# %%
x = [1, 2, 3, 4, 5]  # Prices
y = [5, 4, 3, 2, 1]  # Demand

plt.plot(x, y)

plt.title('Product Demand vs Price')
plt.show()

# %% [markdown]
# ## 🌟 Exercise 5 :

# %%
x = [1, 2, 3, 4, 5]  # Age
y = [75, 80, 88, 95, 105]  # Height in cm

plt.scatter(x, y)

plt.title("Children's Height vs Age")
plt.show()

# %% [markdown]
# ## 🌟 Exercise 6 :

# %%
plt.savefig("Product_demand_vs_price.png")

# %%
plt.savefig("Children's Height vs Age")

# %% [markdown]
# ## 🌟 Exercise 7 :

# %%
x = np.linspace(-10, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(x, y1, color='tab:blue', label='y = sin(x)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('y = sin(x)')
axes[0].legend()

axes[1].scatter(x, y2, marker='o', color='tab:blue', label='y = cos(x)')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].set_title('y = cos(x)')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌟 Exercise 8 :

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10)) 

axes[0].plot(x, y1, color='tab:blue', label='y = sin(x)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].scatter(x, y2, marker='o', color='tab:blue', label='y = cos(x)')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌟 Exercise 9 :

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 10)) 

axes[0].plot(x, y1, color='tab:blue', label='y = sin(x)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].legend()

axes[1].scatter(x, y2, marker='o', color='tab:blue', label='y = cos(x)')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌟 Exercise 10 :

# %%
grades = [88, 90, 95, 92, 88, 90, 88, 85, 93, 92, 90, 87, 95, 90, 88]

# %%
plt.hist(grades, bins=10, color='blue', edgecolor='black')
plt.show()
