# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
oil = pd.read_csv("./oil.csv")
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.shape
# Out:
# (1218, 2)

# %%
oil.index
# Out:
# RangeIndex(start=0, stop=1218, step=1)

# %%
oil.columns
# Out:
# Index(['date', 'dcoilwtico'], dtype='object')

# %%
oil.axes
# Out:
# [RangeIndex(start=0, stop=1218, step=1),
#  Index(['date', 'dcoilwtico'], dtype='object')]

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
oil.head(10)
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %%
oil.tail()
# Out:
#             date  dcoilwtico
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26

# %%
oil.sample(5)
# Out:
#             date  dcoilwtico
# 443   2014-09-12       92.18
# 1102  2017-03-23       47.00
# 146   2013-07-24      105.41
# 150   2013-07-30      103.14
# 161   2013-08-14      106.89

# %%
oil.sample(5, random_state=1234)
# Out:
#             date  dcoilwtico
# 886   2016-05-25       49.10
# 1043  2016-12-30       53.75
# 680   2015-08-11       43.11
# 601   2015-04-22       56.17
# 1206  2017-08-16       46.80

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.describe(include="all").round(2)
# Out:
#               date  dcoilwtico
# count         1218     1175.00
# unique        1218         NaN
# top     2013-01-01         NaN
# freq             1         NaN
# mean           NaN       67.71
# std            NaN       25.63
# min            NaN       26.19
# 25%            NaN       46.40
# 50%            NaN       53.19
# 75%            NaN       95.66
# max            NaN      110.62

# %% [markdown]
# # dataframes

# %%
oil.date
# Out:
# 0       2013-01-01
# 1       2013-01-02
# 2       2013-01-03
# 3       2013-01-04
# 4       2013-01-07
#            ...
# 1213    2017-08-25
# 1214    2017-08-28
# 1215    2017-08-29
# 1216    2017-08-30
# 1217    2017-08-31
# Name: date, Length: 1218, dtype: object

# %%
oil["date"]
# Out:
# 0       2013-01-01
# 1       2013-01-02
# 2       2013-01-03
# 3       2013-01-04
# 4       2013-01-07
#            ...
# 1213    2017-08-25
# 1214    2017-08-28
# 1215    2017-08-29
# 1216    2017-08-30
# 1217    2017-08-31
# Name: date, Length: 1218, dtype: object

# %%
oil["dcoilwtico"].mean()
# Out:
# 67.71436595744682

# %%
oil["dcoilwtico"].nunique()
# Out:
# 998

# %%
oil["dcoilwtico"].sum()
# Out:
# 79564.38

# %%
oil[["date","dcoilwtico"]].iloc[5:10]
# Out:
#          date  dcoilwtico
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %%
oil.iloc[5:104,1:2]
# Out:
#      dcoilwtico
# 5         93.21
# 6         93.08
# 7         93.81
# 8         93.60
# 9         94.27
# ..          ...
# 99        96.29
# 100       95.55
# 101       93.98
# 102       94.12
# 103       93.84
#
# [99 rows x 1 columns]

# %%
oil.loc[:,["date","dcoilwtico"]]
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# # Exercise 3 - Accessing DataFrames
#
# Hi, starting to dive deeper into this data.
#
# I noticed that the first row is the only one from 2013-01-01.
#
# * Can you get me a copy of the DataFrame that excludes that row, and only includes “store_nbr” and “transactions”?
# * Also, can you report the number of unique store numbers?
# * Finally, return the total number of transactions in millions

# %%
transactions = pd.read_csv("./transactions.csv")
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
df_filtered_transaction = transactions[transactions['date'] != '2013-01-01'][['store_nbr', 'transactions']].copy()
df_filtered_transaction
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %% [markdown]
# ### Or another way

# %%
# skip the first row via slicing
transactions. loc[1:, "store_nbr": "transactions"]
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
# Report the number of unique store numbers
num_unique_stores = df_filtered_transaction['store_nbr'].nunique()
num_unique_stores
# Out:
# 54

# %% [markdown]
# ### or

# %%
# calculate sum of store number column
transactions.loc[:, "store_nbr"]. nunique()
# Out:
# 54

# %%
# Return the total number of transactions in millions
total_transactions_millions = df_filtered_transaction['transactions'].sum() / 1e6
total_transactions_millions
# Out:
# 141.478175

# %% [markdown]
# ### Or

# %%
transactions.loc[:,'transactions'].sum() / 1000000
# Out:
# 141.478945

# %% [markdown]
# ## DROPPING ROWS & COLUMS

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.drop("dcoilwtico", axis=1).head()
# Out:
#          date
# 0  2013-01-01
# 1  2013-01-02
# 2  2013-01-03
# 3  2013-01-04
# 4  2013-01-07

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.drop([0], axis=0).head()
# Out:
#          date  dcoilwtico
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21

# %%
oil.drop(range(5), axis=0).head()
# Out:
#          date  dcoilwtico
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %% [markdown]
# ### IDENTIFYING DUBLICATE ROWS

# %%
products = pd.read_csv("./product.csv")
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT
# 0                    22 LB
# 1
# 2
# 3                    50 OZ
# 4                    14 OZ
# ...                    ...
# 92348
# 92349
# 92350
# 92351
# 92352
#
# [92353 rows x 7 columns]

# %%
products.shape
# Out:
# (92353, 7)

# %%
products.nunique()
# Out:
# PRODUCT_ID              92353
# MANUFACTURER             6476
# DEPARTMENT                 44
# BRAND                       2
# COMMODITY_DESC            308
# SUB_COMMODITY_DESC       2383
# CURR_SIZE_OF_PRODUCT     4345
# dtype: int64

# %%
list = products.iloc[:5,1:3]
list
# Out:
#    MANUFACTURER    DEPARTMENT
# 0             2       GROCERY
# 1             2  MISC. TRANS.
# 2            69        PASTRY
# 3            69       GROCERY
# 4            69       GROCERY

# %%
list.nunique()
# Out:
# MANUFACTURER    2
# DEPARTMENT      3
# dtype: int64

# %%
list.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
list.duplicated(subset="MANUFACTURER")
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
list.drop_duplicates()
# Out:
#    MANUFACTURER    DEPARTMENT
# 0             2       GROCERY
# 1             2  MISC. TRANS.
# 2            69        PASTRY
# 3            69       GROCERY

# %%
list.drop_duplicates(subset="MANUFACTURER", keep="last", ignore_index=True)
# Out:
#    MANUFACTURER    DEPARTMENT
# 0             2  MISC. TRANS.
# 1            69       GROCERY

# %% [markdown]
# # Assignment 4: Dropping Data and Duplicates
#
# Hi there!
#
# Can you:
#
# 1. Drop the first row of data? We want it permanently removed.
# 2. Drop the date column but not in place
# 3. Return a dataframe that only includes the last row for each of the stores.

# %%
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
# Drop the first row of data permanently
df_filtered_transaction = df_filtered_transaction.iloc[1:]
df_filtered_transaction.head()
# Out:
#    store_nbr  transactions
# 3          3          3487
# 4          4          1922
# 5          5          1903
# 6          6          2143
# 7          7          1874

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
df_filtered_transaction = transactions

# %%
# Drop the 'date' column (not in place)
df_without_date_column = df_filtered_transaction.drop('date', axis=1, inplace=False)
df_without_date_column.head()
# Out:
#    store_nbr  transactions
# 0         25           770
# 1          1          2111
# 2          2          2358
# 3          3          3487
# 4          4          1922

# %%
# Return a DataFrame that only includes the last row for each store
last_row_per_store = df_filtered_transaction.groupby('store_nbr').last().head()
last_row_per_store
# Out:
#                  date  transactions
# store_nbr
# 1          2017-08-15          1693
# 2          2017-08-15          1737
# 3          2017-08-15          2956
# 4          2017-08-15          1283
# 5          2017-08-15          1310

# %% [markdown]
# ## IDENTIFYING MISSING DATA

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
new_oil = oil.fillna(0)
new_oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01        0.00
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
new_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1218 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1175 entries, 1 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1175 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 27.5+ KB

# %%
oil.fillna({'dcoilvtico': 0.5, 'date': '2020-01-01'})
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %% [markdown]
# ## FILTERING

# %%
oil.loc[oil["date"] == "2013-01-07"]
# Out:
#          date  dcoilwtico
# 4  2013-01-07        93.2

# %%
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT
# 0                    22 LB
# 1
# 2
# 3                    50 OZ
# 4                    14 OZ
# ...                    ...
# 92348
# 92349
# 92350
# 92351
# 92352
#
# [92353 rows x 7 columns]

# %%
products.query("DEPARTMENT in ['GROCERY', 'DRUG GM'] and COMMODITY_DESC == 'BOOKSTORE'")
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND COMMODITY_DESC  \
# 314         36247           769    DRUG GM  National      BOOKSTORE
# 2136       107314           769    DRUG GM  National      BOOKSTORE
# 2639       151037          1580    DRUG GM  National      BOOKSTORE
# 5833       819267          5094    DRUG GM  National      BOOKSTORE
# 5888       819757          2737    DRUG GM  National      BOOKSTORE
# ...           ...           ...        ...       ...            ...
# 92329    18206211          6394    DRUG GM  National      BOOKSTORE
# 92348    18293142          6384    DRUG GM  National      BOOKSTORE
# 92349    18293439          6393    DRUG GM  National      BOOKSTORE
# 92350    18293696          6406    DRUG GM  National      BOOKSTORE
# 92351    18294080          6442    DRUG GM  National      BOOKSTORE
#
#                SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 314               PAPERBACK BOOKS
# 2136              PAPERBACK BOOKS
# 2639              PAPERBACK BOOKS
# 5833            CHILDRENS LOW END
# 5888              PAPERBACK BOOKS
# ...                           ...                  ...
# 92329  HARDBACK/TRADE BEST SELLER
# 92348             PAPERBACK BOOKS
# 92349           CHILDRENS LOW END
# 92350       PAPERBACK BEST SELLER
# 92351             PAPERBACK BOOKS
#
# [1134 rows x 7 columns]

# %%
products.query("DEPARTMENT in ['GROCERY', 'DRUG GM'] and MANUFACTURER > @avg_size")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:229, in Scope.resolve(self, key, is_local)
#     228 if is_local:
# --> 229     return self.scope[key]
#     231 # not a local variable so check in resolvers if we have them
#
# File ~/anaconda3/lib/python3.11/collections/__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# File ~/anaconda3/lib/python3.11/collections/__init__.py:998, in ChainMap.__missing__(self, key)
#     997 def __missing__(self, key):
# --> 998     raise KeyError(key)
#
# KeyError: 'avg_size'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     240 try:
#     241     # last ditch effort we look in temporaries
#     242     # these are created when parsing indexing expressions
#     243     # e.g., df[df > 0]
# --> 244     return self.temps[key]
#     245 except KeyError as err:
#
# KeyError: 'avg_size'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 products.query("DEPARTMENT in ['GROCERY', 'DRUG GM'] and MANUFACTURER > @avg_size")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4440, in DataFrame.query(self, expr, inplace, **kwargs)
#    4438 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4439 kwargs["target"] = None
# -> 4440 res = self.eval(expr, **kwargs)
#    4442 try:
#    4443     result = self.loc[res]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4566, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4563     kwargs["target"] = self
#    4564 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4566 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:740, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
#     739     lhs = self._try_visit_binop(x)
# --> 740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:535, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:457, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     455     left = self.visit(node.left, side="left")
#     456 if right is None:
# --> 457     right = self.visit(node.right, side="right")
#     458 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     459 return op, op_class, left, right
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:548, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     547 def visit_Name(self, node, **kwargs):
# --> 548     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/ops.py:86, in Term.__init__(self, name, env, side, encoding)
#      84 tname = str(name)
#      85 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86 self._value = self._resolve_name()
#      87 self.encoding = encoding
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/ops.py:110, in Term._resolve_name(self)
#     105 if local_name in self.env.scope and isinstance(
#     106     self.env.scope[local_name], type
#     107 ):
#     108     is_local = False
# --> 110 res = self.env.resolve(local_name, is_local=is_local)
#     111 self.update(res)
#     113 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:246, in Scope.resolve(self, key, is_local)
#     244     return self.temps[key]
#     245 except KeyError as err:
# --> 246     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: local variable 'avg_size' is not defined

# %%
oilb
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.columns = [col.upper() for col in oil.columns]
oil
# Out:
#             DATE  DCOILWTICO
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.rename(columns={"DATE": "DDATE"}, inplace=True)
oil
# Out:
#            DDATE  DCOILWTICO
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT
# 0                    22 LB
# 1
# 2
# 3                    50 OZ
# 4                    14 OZ
# ...                    ...
# 92348
# 92349
# 92350
# 92351
# 92352
#
# [92353 rows x 7 columns]

# %%
new_products = products.assign(NEWMAN=products["MANUFACTURER"] * 3)
new_products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT  NEWMAN
# 0                    22 LB       6
# 1                                6
# 2                              207
# 3                    50 OZ     207
# 4                    14 OZ     207
# ...                    ...     ...
# 92348                        19152
# 92349                        19179
# 92350                        19218
# 92351                        19326
# 92352                         2292
#
# [92353 rows x 8 columns]
